# %% [markdown]
# ## Exploração / validação:
#
# Entender, validar e evoluir o modelo de dados.
#
# Este notebook NÃO é para criar tabelas em produção.
#
# Ele serve para validar o modelo conceitual / lógico
#
# Conferir se o ORM representa corretamente o DER
#
# Ex: Ver se heranças (Aluno / Professor) fazem sentido
#
#     Validar cardinalidades (relationship, back_populates)

# %%
from src.models.usuario import Usuario
from src.models.usuario import Aluno

issubclass(Aluno, Usuario)

# %% [markdown]
# ## Explorar o mapeamento ORM
#
# **Você pode inspecionar:**
# Isso ajuda a entender como o SQLAlchemy está “vendo” seu modelo
#
# Detectar FK errada antes de ir para o banco

# %%
Usuario.__table__
Usuario.__mapper__.relationships
